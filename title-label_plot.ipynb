# %%
import matplotlib.pyplot as plt

# %%
x = ['Mon' , 'Tue', 'Wed', 'Thr', 'Fri', 'Sat', 'Sun' ]
y = [100,220,500,400,1000,2000,1200]

# %%
plt.plot(x,y)
plt.title("Sales this week")
plt.xlabel("Days")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
