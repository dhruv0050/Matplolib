# %%
import matplotlib.pyplot as plt

# %%
scores = [
    35, 40, 42, 45, 47, 49, 50, 51, 52, 53,
    55, 55, 56, 57, 58, 59, 60, 60, 61, 62,
    63, 64, 65, 65, 66, 67, 67, 68, 69, 70,
    71, 72, 72, 73, 74, 75, 75, 76, 77, 77,
    78, 78, 79, 80, 81, 82, 83, 84, 85, 85,
    86, 87, 88, 89, 90, 92, 94, 96, 97, 98
]

# %%
plt.hist(scores, bins = 5, color = 'orange', edgecolor = 'black')
plt.title('Distribution of Scores')
plt.xlabel('Scores')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
